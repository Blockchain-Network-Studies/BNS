# %%
#@title Mount Drive
from google.colab import drive
drive.mount('/content/drive')
print('Authenticated')
# Out:
# Mounted at /content/drive
# Authenticated

# %%
cd /content/drive/MyDrive/Network Study/2023 Sep Revise/Data/
# Out:
# /content/drive/MyDrive/Network Study/2023 Sep Revise/Data

# %%
# !pip install cpnet
# Out:
# Collecting cpnet
#   Downloading cpnet-0.0.21-py3-none-any.whl (30 kB)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from cpnet) (3.2.1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from cpnet) (1.23.5)
# Collecting simanneal>=0.4.2 (from cpnet)
#   Downloading simanneal-0.5.0-py2.py3-none-any.whl (5.6 kB)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from cpnet) (1.11.3)
# Requirement already satisfied: numba>=0.50.0 in /usr/local/lib/python3.10/dist-packages (from cpnet) (0.58.1)
# Requirement already satisfied: joblib>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from cpnet) (1.3.2)
# Requirement already satisfied: plotly>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from cpnet) (5.15.0)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from cpnet) (0.12.2)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from cpnet) (1.5.3)
# Requirement already satisfied: tqdm>=4.49.0 in /usr/local/lib/python3.10/dist-packages (from cpnet) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.50.0->cpnet) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->cpnet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->cpnet) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.10.0->cpnet) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.10.0->cpnet) (23.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn>=0.11.0->cpnet) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.0->cpnet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.0->cpnet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.0->cpnet) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.0->cpnet) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.0->cpnet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.0->cpnet) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.0->cpnet) (1.16.0)
# Installing collected packages: simanneal, cpnet
# Successfully installed cpnet-0.0.21 simanneal-0.5.0

# %%
import pandas as pd
import cpnet
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_csv('AAVE transaction data_after preprocessing.csv')
df_time_partition= df.groupby(['timestamp'])['to_address'].agg(['nunique']).reset_index()
df_time_partition = df_time_partition.drop(['nunique'], axis=1)


significant_test = []
date = 0
for i in range(0,len(df_time_partition)):
    df_1 = df.loc[df['timestamp']==df_time_partition['timestamp'][i]]

    #Build the daily transaction network
    G = nx.from_pandas_edgelist(df_1, 'from_address', 'to_address', 'value', nx.Graph())

    #Extract the core-periphery structure by BE algorithm
    alg = cpnet.BE()
    alg.detect(G)
    c = alg.get_pair_id()
    x = alg.get_coreness()

    #Significant test
    sig_c, sig_x, significant, p_values = cpnet.qstest(
        c, x, G, alg, significance_level=0.05, num_of_rand_net=100, num_of_thread=16)
    significant_test.append(significant)
    date+=1
    print(date)
    print(significant)


significant_test = pd.DataFrame(significant_test)
significant_test['date'] = significant_test['timestamp']

significant_test.to_csv('core_periphery_significant_test.csv')
